# %%
pip install arxivscraper
# Out:
# Collecting arxivscraper
#   Downloading arxivscraper-0.0.5-py3-none-any.whl (6.1 kB)
# Installing collected packages: arxivscraper
# Successfully installed arxivscraper-0.0.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import arxivscraper
scraper = arxivscraper.Scraper(category='physics:cond-mat', date_from='2023-03-23',date_until='2023-03-35')

# %%
output = scraper.scrape()
# Out:
# fetching up to  1000 records...
# fetching is completed in 4.2 seconds.
# Total number of records 265

# %%
import pandas as pd
cols = ('id', 'title', 'categories', 'abstract', 'doi', 'created', 'updated', 'authors')
df = pd.DataFrame(output,columns=cols)
df
# Out:
#              id                                              title  \
# 0     1406.4323  $\gamma$-ray spectra and enhancement factors f...
# 1    1611.01255  structure evolutions in atoms of the elements ...
# 2    1705.10225                  bayesian stochastic blockmodeling
# 3    1903.09962  on structure-stabilizing electronic interferen...
# 4    1912.11034  vortical effects in dirac fluids with vector, ...
# ..          ...                                                ...
# 260  2303.13476  calculating the many-body density of states on...
# 261  2303.13498  sign structure in the square-lattice $t$-$t^\p...
# 262  2303.13506           the quantization model of neural scaling
# 263  2303.13507  quasi-particle propagation across semiconducto...
# 264  2303.13513  majorana-magnon interactions in topological sh...
#
#                                      categories  \
# 0                physics.atom-ph cond-mat.other
# 1                             cond-mat.mtrl-sci
# 2    stat.ml cond-mat.stat-mech physics.data-an
# 3                             cond-mat.mtrl-sci
# 4              hep-th cond-mat.mes-hall nucl-th
# ..                                          ...
# 260                 quant-ph cond-mat.stat-mech
# 261           cond-mat.str-el cond-mat.supr-con
# 262                       cs.lg cond-mat.dis-nn
# 263                             cond-mat.str-el
# 264                  cond-mat.mes-hall quant-ph
#
#                                               abstract  \
# 0    many-body theory is developed to calculate the...
# 1    differentiating structural evolution from stru...
# 2    this chapter provides a self-contained introdu...
# 3    this study deals with cubic crystals where the...
# 4    helicity of free massless dirac fermions is a ...
# ..                                                 ...
# 260  quantum statistical mechanics allows us to ext...
# 261  understanding the doped mott insulator is a ce...
# 262  we propose the $\textit{quantization model}$ o...
# 263  as a prototypical example for a heterostructur...
# 264  a chain of magnetic impurities deposited on th...
#
#                                  doi     created     updated  \
# 0     10.1103/physrevlett.114.093201  2014-06-17  2015-01-07
# 1                                     2016-11-03  2023-03-22
# 2         10.1002/9781119483298.ch11  2017-05-29  2023-03-22
# 3                                     2019-03-24  2023-03-22
# 4    10.1140/epjc/s10052-023-11244-0  2019-12-23  2023-03-21
# ..                               ...         ...         ...
# 260                                   2023-03-23
# 261                                   2023-03-23
# 262                                   2023-03-23
# 263                                   2023-03-23
# 264                                   2023-03-23
#
#                                                authors
# 0                        [d. g. green, g. f. gribakin]
# 1                                        [mubarak ali]
# 2                                   [tiago p. peixoto]
# 3                                   [heinrich solbrig]
# 4                  [victor e. ambrus, m. n. chernodub]
# ..                                                 ...
# 260  [alessandro summer, cecilia chiaracane, mark t...
# 261  [xin lu, jia-xin zhang, shou-shu gong, d. n. s...
# 262  [eric j. michaud, ziming liu, uzay girit, max ...
# 263  [jan verlage, friedemann queisser, nikodem szp...
# 264  [pei-xin shen, vivien perrin, mircea trif, pas...
#
# [265 rows x 8 columns]
